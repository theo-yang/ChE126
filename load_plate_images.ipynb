# %%
import glob
import skimage
import skimage.io
import skimage.filters
import numpy as np
from skimage import feature
from skimage.filters import sobel
from skimage import exposure

# %%
im_list = list( glob.glob("data/*/*.jpg"))
# Load images and store in list [phase, RFP, CFP, YFP]
ims = [skimage.io.imread(im_name,as_gray = True) for im_name in im_list]

# %%
skimage.io.imshow(ims[58])

# %%
p2, p98 = np.percentile(ims[58], (2, 98))
y = exposure.rescale_intensity(ims[58],in_range=(p2, p98))
skimage.io.imshow(y)
