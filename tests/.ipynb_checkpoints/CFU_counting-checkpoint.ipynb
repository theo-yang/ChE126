# %% [markdown]
# ## Tests for CFU counting

# %%
from skimage.io import imshow
from importlib import reload
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../functions/')
import functions

# %% [markdown]
# Get data from 11-16-19

# %%
reload(functions);

# %%
images = functions.get_image_data('..\\data\\111519\\MEACHL_O2_3.JPG')
images.head()
# Out:
# check
#     Date Environ  CHL -Log(Dilution)  \
# 0  11519      O2  Yes              3
#
#                                                Image
# 0  [[0.01568627450980392, 0.0196078431372549, 0.0...

# %% [markdown]
# Get image of O2 conditions with CHL and dilution = 10^-2

# %%
filter = (images['Environ'] == 'O2') & (images['CHL'] == 'Yes') & (images['-Log(Dilution)'] == '3')
im = images[filter]['Image'].item()
imshow(im)
plt.show()

# %% [markdown]
# Now, let's find the roi.

# %%
edge = functions.plate_edge_detector(im)
image_cropped, roi_matrix = functions.define_circular_roi(im,edge)
imshow(image_cropped * roi_matrix)
plt.show()
# Out:
# C:\Users\Theo Yang\Anaconda3\lib\site-packages\skimage\util\dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-0b5931cf2e4b> in <module>()
#       1 edge = functions.plate_edge_detector(im)
#       2 image_cropped, roi_matrix = functions.define_circular_roi(im,edge)
# ----> 3 imshow(image_cropped * roi_matrix)
#       4 plt.show()
#
# ValueError: operands could not be broadcast together with shapes (1845,1874) (1920,3328)
